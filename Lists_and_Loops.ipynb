# %%
acronyms = []

acronyms.append("NASA")
acronyms.append("FBI")
acronyms.append("CIA")
acronyms.append("UN")

print(acronyms) 

# Delete the first element of the list
del acronyms[3]
print(acronyms)
# Out:
# ['NASA', 'FBI', 'CIA', 'UN']
# ['NASA', 'FBI', 'CIA']

# %%
# Checking a list for an element
if "FBI" in acronyms:
    print("FBI is in the list")
if "NASA" in acronyms:
    print("NASA is in the list")
# Out:
# FBI is in the list
# NASA is in the list

# %%
for n in acronyms:
    print(n)
# Out:
# NASA
# FBI
# CIA

# %%
# Expenses calculation
expenses = [10.50, 8, 5, 15, 20, 5, 3]
total = 0
for expense in expenses:
    total += expense
print(f"Total expenses for the week: {total}")

# printing the total using a separator and a comma
print("You spent $", total, sep='')

# Using the sum function to calculate the total expenses
print("You spent $", sum(expenses), sep='')
# Out:
# Total expenses for the week: 66.5
# You spent $66.5
# You spent $66.5

# %%
expenses = []

my_expense = input("Enter an expense for the week: \n")
for i in range(len(my_expense.split(','))):
    num = my_expense.split(',')
    expenses.append(float(num[i]))
print("You spent $", sum(expenses), sep='')
# Out:
# You spent $162.5

# %%
# Understading range in loops
# Range have 3 parameters: start, stop, step
# start is the number to start counting from (default is 0)
# stop is the number to stop counting at (not included in the range)
# step is the number to increment by (default is 1)
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
menu = {"breakfast" : ["eggs", "bacon", "toast", "pancakes", "waffles"],
        "lunch" : ["sandwich", "salad", "soup", "burger", "pizza"],
        "dinner" : ["steak", "chicken", "fish", "pasta", "rice"]}


lunch = ["sandwich", "salad", "soup", "burger", "pizza"]
dinner = ["steak", "chicken", "fish", "pasta", "rice"]

select_food_list = input("What meal do you want to eat? (breakfast, lunch, dinner) \n")
if select_food_list == "breakfast":
    for food in menu["breakfast"]:
        print(food)
elif select_food_list == "lunch":
    for food in menu["lunch"]:
        print(food)
elif select_food_list == "dinner":
    for food in menu["dinner"]:
        print(food)
else:
    print("Invalid meal selection.")
# Out:
# sandwich
# salad
# soup
# burger
# pizza

# %%
menus = {"breakfast" : ["eggs", "bacon", "toast", "pancakes", "waffles"],
        "lunch" : ["sandwich", "salad", "soup", "burger", "pizza"],
        "dinner" : ["steak", "chicken", "fish", "pasta", "rice"]}



for name, menu in menus.items():
    print(f"{name.capitalize()}:")
    for food in menu:
        print(f" - {food}")

for food in menu:
    print(f" - {food}")
# Out:
# Breakfast:
#  - eggs
#  - bacon
#  - toast
#  - pancakes
#  - waffles
# Lunch:
#  - sandwich
#  - salad
#  - soup
#  - burger
#  - pizza
# Dinner:
#  - steak
#  - chicken
#  - fish
#  - pasta
#  - rice
#  - steak
#  - chicken
#  - fish
#  - pasta
#  - rice
